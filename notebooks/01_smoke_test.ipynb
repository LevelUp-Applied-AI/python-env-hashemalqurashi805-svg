# %%
import pandas as pd

# قراءة الملف (استخدمنا .. للخروج من مجلد notebooks والوصول لمجلد data)
df = pd.read_csv("../data/sample.csv")

# عرض المعلومات للتأكد
print("Shape of Data:", df.shape)
df.head()
# Out:
# Shape of Data: (5, 3)
#     name  score  passed
# 0  Alice     85    True
# 1    Bob     72    True
# 2  Carol     60   False
# 3  Diana     91    True
# 4    Eve     45   False
