# %%
import pandas as pd

df = pd.read_csv("data/sample.csv")
print("Shape:", df.shape)
print(df.head())
print(df.describe())
# Out:
# Shape: (5, 3)
#       product  price  units_sold
# 0    Notebook  12.99         120
# 1         Pen   1.50         450
# 2    Backpack  39.99          75
# 3  Calculator  19.99          60
# 4      Marker   2.99         200
#            price  units_sold
# count   5.000000    5.000000
# mean   15.492000  181.000000
# std    15.642251  159.937488
# min     1.500000   60.000000
# 25%     2.990000   75.000000
# 50%    12.990000  120.000000
# 75%    19.990000  200.000000
# max    39.990000  450.000000
